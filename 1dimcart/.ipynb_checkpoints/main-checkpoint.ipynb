# %%
import gymnasium as gym
import numpy as np

env = gym.make("CartPole-v1")

bins = 20
state_space = [
    np.linspace(-4.8, 4.8, bins),
    np.linspace(-5, 5, bins),
    np.linspace(-0.418, 0.418, bins),
    np.linspace(-5, 5, bins)
]

def discretize(obs):
    return tuple(np.digitize(o, b) for o, b in zip(obs, state_space))

q_table = np.zeros([bins]*4 + [env.action_space.n])
alpha = 0.1
gamma = 0.99
epsilon = 0.1
episodes = 10000

for ep in range(episodes):
    obs, _ = env.reset()
    state = discretize(obs)
    done = False
    total_reward = 0

    while not done:
        if np.random.random() < epsilon:
            action = env.action_space.sample()
        else:
            action = np.argmax(q_table[state])

        next_obs, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        next_state = discretize(next_obs)

        q_table[state][action] += alpha * (reward + gamma * np.max(q_table[next_state]) - q_table[state][action])
        state = next_state
        total_reward += reward

    if ep % 50 == 0:
        print(f"Episode {ep}, Total Reward: {total_reward}")

env.close()
# Out:
# Episode 0, Total Reward: 9.0
# Episode 50, Total Reward: 9.0
# Episode 100, Total Reward: 9.0
# Episode 150, Total Reward: 9.0
# Episode 200, Total Reward: 10.0
# Episode 250, Total Reward: 9.0
# Episode 300, Total Reward: 10.0
# Episode 350, Total Reward: 9.0
# Episode 400, Total Reward: 9.0
# Episode 450, Total Reward: 8.0
# Episode 500, Total Reward: 9.0
# Episode 550, Total Reward: 10.0
# Episode 600, Total Reward: 10.0
# Episode 650, Total Reward: 9.0
# Episode 700, Total Reward: 10.0
# Episode 750, Total Reward: 10.0
# Episode 800, Total Reward: 10.0
# Episode 850, Total Reward: 9.0
# Episode 900, Total Reward: 9.0
# Episode 950, Total Reward: 10.0
# Episode 1000, Total Reward: 9.0
# Episode 1050, Total Reward: 9.0
# Episode 1100, Total Reward: 8.0
# Episode 1150, Total Reward: 9.0
# Episode 1200, Total Reward: 9.0
# Episode 1250, Total Reward: 9.0
# Episode 1300, Total Reward: 9.0
# Episode 1350, Total Reward: 10.0
# Episode 1400, Total Reward: 8.0
# ...

# %%
import gymnasium as gym
import time

env = gym.make("CartPole-v1", render_mode="human")

num_episodes = 5  # visualize 5 episodes
print("Visualizing BEFORE training (random actions)...")

for ep in range(num_episodes):
    obs, _ = env.reset()
    done = False
    step = 0
    while not done:
        action = env.action_space.sample()
        obs, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        step += 1
        time.sleep(0.001)
    print(f"Episode {ep+1} finished after {step} steps")

env.close()
# Out:
# Visualizing BEFORE training (random actions)...
# Episode 1 finished after 39 steps
# Episode 2 finished after 20 steps
# Episode 3 finished after 13 steps
# Episode 4 finished after 40 steps
# Episode 5 finished after 15 steps

# %%
import gymnasium as gym
import numpy as np
import time

# Create environment with rendering
env = gym.make("CartPole-v1", render_mode="human")

# Same discretization function and Q-table from your training
bins = 10
state_space = [
    np.linspace(-4.8, 4.8, bins),
    np.linspace(-5, 5, bins),
    np.linspace(-0.418, 0.418, bins),
    np.linspace(-5, 5, bins)
]

def discretize(obs):
    return tuple(np.digitize(o, b) for o, b in zip(obs, state_space))

# Load your trained Q-table (from previous training)
# For demonstration, assuming q_table is already trained in memory
# If not, you can run the training snippet first

obs, _ = env.reset()
state = discretize(obs)
done = False

print("Visualizing AFTER training (Q-learning agent)...")
while not done:
    action = np.argmax(q_table[state])  # take best action from Q-table
    next_obs, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    state = discretize(next_obs)
    time.sleep(0.001)  # slow down for visualization

env.close()
# Out:
# Visualizing AFTER training (Q-learning agent)...
